# %% [markdown]
# ![a.JPG](attachment:a.JPG)
# ![cc.JPG](attachment:cc.JPG)

# %%
class Employee:
    
    def __init__(self, employeeId, employeeName, ageRole, status = "In Service"):
        self.employeeId = employeeId
        self.employeeName = employeeName
        self.ageRole = ageRole
        self.status = status
class Organization:
    
    def __init__(self,emp_list):
        self.el = emp_list
        
    def updateEmployeeStatus(self,age_value):

        for i in self.el:
            
            if i.ageRole > age_value:
                i.status = "Retirement Due"
            else:
                i.status = "In Service"
        
        Organization.countEmployees(self)
        
        for i in self.el:
            print(i.employeeId, i.employeeName, i.status)
        
    def countEmployees(self):
        count = 0
        
        for i in self.el:
            if i.status == "Retirement Due":
                count += 1
                
        print("Count of employee updated=",count)
            
if __name__ == "__main__":
    
    N = int(input())
    emp_list = []
    for i in range(N):
        id = int(input())
        name = input()
        age = int(input())
        emp_list.append(Employee(id,name,age))
       
    retire_due = int(input())
    obj1 = Organization(emp_list)
    obj1.updateEmployeeStatus(retire_due)
#     obj1.countEmployees()
# Out:
# 4
# 101
# John M
# 6
# 102
# Mitul Barua
# 4
# 103
# Rosy Borah
# 3
# 104
# Reza
# 6
# 5
# Count of employee updated= 2
# 101 John M Retirement Due
# 102 Mitul Barua In Service
# 103 Rosy Borah In Service
# 104 Reza Retirement Due
