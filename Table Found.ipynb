# %% [markdown]
# ![s1.JPG](attachment:s1.JPG)
# ![s2.JPG](attachment:s2.JPG)
# ![s3.JPG](attachment:s3.JPG)
# ![s4.JPG](attachment:s4.JPG)

# %%
class Table:
    def __init__(self, tableNo, waiterName, status):
        self.tn = tableNo
        self.wn = waiterName
        self.st = status
        
def findWaiterWiseTotalNoOdTables(t_list):
    w_list = {}
    for i in t_list:
        if i.wn in w_list:
            w_list[i.wn] += 1
        else:
            w_list[i.wn] = 1
    
    return w_list

def findWaiterNameByTableNo(t_list, tb_no):
    for i in t_list:
        if i.tn == tb_no:
            return i.wn
    
    return None   

if __name__ == "__main__":
    N = int(input())
    t_list = []
    for i in range(N):
        tno = int(input())
        wname = input()
        status = input()
        t_list.append(Table(tno, wname, status))
        
    
    tb_no = int(input())
    
    a = findWaiterWiseTotalNoOdTables(t_list)
    for i in sorted(a.keys()):
        print("{}-{}".format(i,a[i]))
        
    b = findWaiterNameByTableNo(t_list, tb_no)
    if b == None:
        print("No Table Found")
    else:
        print(b)
# Out:
# 5
# 101
# Rahul
# Delivered
# 102
# Nikhil
# Not Deliverd
# 103
# Aman
# Deliverd
# 104
# Basanta
# Not Deliverd
# 105
# Gaurav
# Not Deliverd
# 109
# Aman-1
# Basanta-1
# Gaurav-1
# Nikhil-1
# Rahul-1
# No Table Found
